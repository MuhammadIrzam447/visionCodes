# %% [markdown]
# <a href="https://colab.research.google.com/github/MuhammadIrzam447/visionCodes/blob/master/Debuggingv3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Testing Multi-model performance for 100% images and _% text.
# Updated Validation Dataset Class and Validation Loop

# %%
from google.colab import drive
import pandas as pd
import os
from PIL import Image
import torch
from torchvision import datasets, transforms
import torchvision.models as models
from torchvision.datasets import ImageFolder
import torchvision
import torch.nn as nn
import torch.optim as optim
from sklearn.metrics import confusion_matrix
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from PIL import UnidentifiedImageError
from sklearn.metrics import classification_report
# import patoolib

# %%
if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# # Loading Validation Dataset and Preprocessing

# %%
save_dir = '/content/Model/ResNet_MultiModel_v1.0'
load_path = os.path.join(save_dir, 'model.pth')

# Create an instance of the ResNet model
resnet = torchvision.models.resnet101(pretrained=False)
resnet.fc = nn.Linear(2048, 52)

# Load the saved model parameters
resnet.load_state_dict(torch.load(load_path))

# Set the model to evaluation mode and respective device
resnet.eval()
resnet.to(device)

# %%
val_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# %%
class ValidationDataset(torch.utils.data.Dataset):
    def __init__(self, data_dir, val_transform):
        self.data_dir = data_dir
        self.dataset = datasets.ImageFolder(data_dir)
        self.classes = self.dataset.classes
        self.class_lengths = self._compute_class_lengths()
        self.val_transform = val_transform

        # Load only 50% of data from each class
        self.selected_indices = []
        for class_idx in range(len(self.classes)):
            indices = [idx for idx, (_, label) in enumerate(self.dataset.samples) if label == class_idx]
            indices_3 = [idx for idx in indices if self.dataset.samples[idx][0].endswith("_3.png")]    # _3.png are the encoded_text images
            indices_4 = [idx for idx in indices if self.dataset.samples[idx][0].endswith("_4.png")]    # _4.png are the actual images

            # Include all files ending with "_4.png"
            self.selected_indices.extend(indices_4)

            # Randomly select 50% of files ending with "_3.png"
            num_samples_3 = len(indices_3)
            num_samples_to_load_3 = int(1 * num_samples_3) # change the value to change percentage of data <<<<<<<<<<<<<
            # selected_indices_3 = np.random.choice(indices_3, num_samples_to_load_3, replace=False)

            # Append the selected indices to the selected_indices list
            self.selected_indices.extend(indices_3)

        print("Selected Indices:", len(self.selected_indices))
        # for idx in self.selected_indices:
          # print(self.dataset.samples[idx][0])

    def _compute_class_lengths(self):
        class_lengths = {cls: 0 for cls in self.classes}

        for _, label in self.dataset.samples:
            class_lengths[self.classes[label]] += 1

        return class_lengths

    def __getitem__(self, index):
        print("Entered get_item")
        img, label = self.dataset[self.selected_indices[index]]
        filename = self.dataset.samples[self.selected_indices[index]][0]
        image_3 = None
        image_4 = None
        if filename.endswith("_4.png"):
                image_4 = img
                image_4_path = filename
                print("image_4_path: ", str(filename))
                image_3_path = filename.replace('_4.png', '_3.png')
                print("image_3_path: ", str(image_3_path))
                image_3 = self._load_image(image_3_path)
        else:
                image_3 = img
                image_3_path = filename
                print("image_3_path: ", str(filename))
                image_4_path = filename.replace('_3.png', '_4.png')
                print("image_4_path: ", str(image_4_path))
                image_4 = self._load_image(image_4_path)


        return image_3, image_4, label, image_3_path, image_4_path

    def _load_image(self, path):
        image = Image.open(path)
        return image

    def __len__(self):
        return len(self.selected_indices)

# %%
valPath = "/content/Data/mulitmodal_img_enc_txt/images-val"
val_dataset = ValidationDataset(valPath,val_transform)
# Out:
# Selected Indices: 43738

# %%
from torchvision.transforms import ToTensor

def custom_collate(batch):
    to_tensor = ToTensor()

    images_3 = [to_tensor(item[0]) for item in batch]
    images_4 = [to_tensor(item[1]) if item[1] is not None else None for item in batch]
    labels = [torch.tensor(item[2]) for item in batch]  # Convert labels to tensors

    # Filter out None values from images_4
    images_4 = [img for img in images_4 if img is not None]

    # Convert the list of images to tensors
    images_3 = torch.stack(images_3) if images_3 else None
    images_4 = torch.stack(images_4) if images_4 else None

    # Print the filenames in each list
    print("Filenames in images_3 list:")
    for item in batch:
        if item[0] is not None:
            print(item[3])

    print("Filenames in images_4 list:")
    for item in batch:
        if item[1] is not None:
            print(item[4])

    return images_3, images_4, labels

# %%
batch_size = 12
validation_data_loader = torch.utils.data.DataLoader(val_dataset, batch_size=batch_size, shuffle=False, collate_fn=custom_collate)

# %%
print("Number of samples:", len(val_dataset))
print("Number of classes:", len(val_dataset.classes))
# Out:
# Number of samples: 43738
# Number of classes: 52

# %% [markdown]
# # Validation

# %%
resnet.eval()

# Initialize lists to store the average probabilities and true labels
predicted_labels = []
true_labels = []

# Iterate over the dataloader in your testing loop
for images_3, images_4, labels in validation_data_loader:
    # Move the images and labels to the device (e.g., GPU) if available
    images_3 = images_3.to(device)
    # images_4 = images_4.to(device)

    # logits_4 = resnet(images_4)
    logits_3 = resnet(images_3)
    logits_4 = torch.zeros_like(logits_3)

    # Compute the probabilities using softmax along the class dimension
    probabilities_3 = torch.softmax(logits_3, dim=1)
    probabilities_4 = torch.softmax(logits_4, dim=1)

    # Average the probabilities for each pair
    avg_probabilities_batch = (probabilities_3 + probabilities_4) / 2

    # Append the average probabilities to the list
    predicted_labels.extend(avg_probabilities_batch.cpu().tolist())

    # labels = torch.tensor(labels).to(device)
    # Append the true labels to the list
    true_labels.extend(labels)
# Out:
# Streaming output truncated to the last 5000 lines.
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474067.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474067.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474082.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474082.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474193.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474193.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474900.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474900.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475083.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475083.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475204.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475204.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475604.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475604.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475666.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475666.jpg_4.png
# Filenames in images_3 list:
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473170.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473212.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473225.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473273.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474067.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474082.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474193.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474900.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475083.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475204.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475604.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475666.jpg_3.png
# Filenames in images_4 list:
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473170.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473212.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473225.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175473273.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474067.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474082.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474193.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175474900.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475083.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475204.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475604.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175475666.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510069.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510069.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510079.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510079.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510084.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510084.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510088.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510088.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513907.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513907.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513914.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513914.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588054.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588054.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588064.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588064.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588065.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588065.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588078.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588078.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588080.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588080.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588085.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588085.jpg_4.png
# Filenames in images_3 list:
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510069.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510079.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510084.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510088.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513907.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513914.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588054.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588064.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588065.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588078.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588080.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588085.jpg_3.png
# Filenames in images_4 list:
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510069.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510079.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510084.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175510088.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513907.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175513914.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588054.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588064.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588065.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588078.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588080.jpg_4.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588085.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588088.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588088.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588096.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588096.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588102.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588102.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588303.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588303.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588324.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588324.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588330.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588330.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588336.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588336.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588341.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588341.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588343.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588343.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588348.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588348.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588355.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588355.jpg_4.png
# Entered get_item
# image_3_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588356.jpg_3.png
# image_4_path:  /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588356.jpg_4.png
# Filenames in images_3 list:
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588088.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588096.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588102.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588303.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588324.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588330.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175588336.jpg_3.png
# /content/Data/mulitmodal_img_enc_txt/images-val/@vite_bullone/175
classes))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       118
#            1       0.00      0.00      0.00      3758
#            2       0.00      0.00      0.00       690
#            3       0.00      0.00      0.00        96
#            4       0.00      0.00      0.00       264
#            5       0.00      0.00      0.00       352
#            6       0.00      0.00      0.00      2138
#            7       0.00      0.00      0.00       296
#            8       0.23      0.55      0.33      1326
#            9       0.00      0.00      0.00      1284
#           10       0.00      0.00      0.00       272
#           11       0.00      0.00      0.00        70
#           12       0.00      0.00      0.00       224
#           13       0.00      0.00      0.00      1684
#           14       0.00      0.00      0.00      3110
#           15       0.00      0.00      0.00        72
#           16       0.00      0.00      0.00       102
#           17       0.00      0.00      0.00       412
#           18       0.00      0.00      0.00       118
#           19       0.00      0.00      0.00        86
#           20       0.00      0.00      0.00        66
#           21       0.10      0.74      0.17      3852
#           22       0.00      0.00      0.00       562
#           23       0.00      0.00      0.00      1268
#           24       0.00      0.00      0.00       540
#           25       0.00      0.00      0.00       392
#           26       0.00      0.00      0.00       900
#           27       0.11      0.88      0.19      1394
#           28       0.00      0.00      0.00      1390
#           29       0.00      0.00      0.00       292
#           30       0.00      0.00      0.00       170
#           31       0.17      0.05      0.07       662
#           32       0.00      0.00      0.00       108
#           33       0.00      0.00      0.00      2392
#           34       0.00      0.00      0.00       146
#           35       0.00      0.00      0.00       296
#           36       0.00      0.00      0.00       476
#           37       0.00      0.00      0.00       292
#           38       0.00      0.00      0.00       284
#           39       0.00      0.00      0.00       654
#           40       0.00      0.00      0.00       406
#           41       0.00      0.00      0.00      1044
#           42       0.00      0.00      0.00       314
#           43       0.00      0.00      0.00      2704
#           44       0.00      0.00      0.00       508
#           45       0.00      0.00      0.00        74
#           46       0.00      0.00      0.00       160
#           47       0.00      0.00      0.00       232
#           48       0.00      0.00      0.00       758
#           49       0.58      0.04      0.08       318
#           50       0.00      0.00      0.00       212
#           51       0.00      0.00      0.00      4400
#
#     accuracy                           0.11     43738
#    macro avg       0.02      0.04      0.02     43738
# weighted avg       0.03      0.11      0.03     43738
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
labels = ['Accuracy', 'Precision', 'Recall', 'F1-score']
values = [accuracy, precision, recall, f1]

x = np.arange(len(labels))

fig, ax = plt.subplots(figsize=(5, 4))
bars = ax.bar(x, values)

# labels, title, and legend
ax.set_xlabel('Metrics')
ax.set_ylabel('Score')
ax.set_title('Model Performance Metrics')
ax.set_xticks(x)
ax.set_xticklabels(labels)

# scores on top of each bar
for i, bar in enumerate(bars):
    score = values[i]
    ax.text(bar.get_x() + bar.get_width() / 2, bar.get_height(), f'{score:.2f}', ha='center', va='bottom')

plt.show()

# %%
# Count the occurrences of each label in predicted and true labels
predicted_counts = np.bincount(predicted_classes)
true_counts = np.bincount(actual_labels)

# Get the unique labels
labels = np.unique(np.concatenate((predicted_classes, actual_labels)))

# Set the x-axis range
x = np.arange(len(labels))

# Set the width of the bars
width = 0.35

# Plot the predicted and true label counts
fig, ax = plt.subplots(figsize=(20, 8))
ax.bar(x - width/2, predicted_counts, width, label='Predicted Labels')
ax.bar(x + width/2, true_counts, width, label='True Labels')

# Add labels, title, and legend
ax.set_xlabel('Labels')
ax.set_ylabel('Count')
ax.set_title('Distribution of Predicted and True Labels')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

plt.show()
